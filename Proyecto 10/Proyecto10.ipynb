# %% [markdown]
# # Proyecto 10
# Yibby Daniela Gonzalez Forero
#
# Juan Sebastián Ruiz Caro

# %% [markdown]
# ## Municipio

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
abigeato = pd.read_excel('/content/abigeato_2019_3.xlsx')
amenazas = pd.read_excel('/content/amenazas_2019_1.xlsx')
delitos_sexuales = pd.read_excel('/content/delitos_sexuales_2019_0.xlsx')
extorsion = pd.read_excel('/content/extorsion_2019_4.xlsx')
homicidios = pd.read_excel('/content/homicidios_2019_3.xlsx')
homicidios_en_accidente_de_transito = pd.read_excel('/content/homicidios_en_accidente_de_transito_2019.xlsx')
hurto_a_comercio = pd.read_excel('/content/hurto_a_comercio_2019_0.xlsx')
hurto_a_entidades_financieras = pd.read_excel('/content/hurto_a_entidades_financieras_2019_3.xlsx')
hurto_a_personas = pd.read_excel('/content/hurto_a_personas_2019_0.xlsx')
hurto_a_residencias = pd.read_excel('/content/hurto_a_residencias_2019_0.xlsx')
hurto_automotores = pd.read_excel('/content/hurto_automotores_2019_0.xlsx')
hurto_motocicletas = pd.read_excel('/content/hurto_motocicletas_2019_0.xlsx')
lesiones_en_accidente_de_transito = pd.read_excel('/content/lesiones_en_accidente_de_transito_2019_0.xlsx')
lesiones_personales = pd.read_excel('/content/lesiones_personales_2019_0.xlsx')
pirateria_terrestre = pd.read_excel('/content/pirateria_terrestre_2019_3.xlsx')
secuestro = pd.read_excel('/content/secuestro_2019_3.xlsx')
terrorismo = pd.read_excel('/content/terrorismo_2019_2.xlsx')
violencia_intrafamiliar = pd.read_excel('/content/violencia_intrafamiliar_2019_0.xlsx')

# %%
terrorismo.columns 
abigeato = pd.read_excel('/content/abigeato_2019_3.xlsx')

# %%
abigeato = abigeato.filter(['CODIGO DANE','MUNICIPIO','CANTIDAD'], axis = 1)
abigeato['CODIGO DANE'] = abigeato['CODIGO DANE']/1000
abigeato.dropna()
#abigeato = abigeato.sort_values(by='MUNICIPIO') ; abigeato
abigeato1 = abigeato.groupby(['CODIGO DANE','MUNICIPIO']).sum()

# %%
amenazas = amenazas.filter(['CODIGO DANE','MUNICIPIO','CANTIDAD'], axis = 1)
amenazas['CODIGO DANE'] = amenazas['CODIGO DANE']/1000
amenazas.dropna()
#amenazas = amenazas.sort_values(by='MUNICIPIO') ; amenazas
amenazas1 = amenazas.groupby(['CODIGO DANE','MUNICIPIO']).sum()

# %%
delitos_sexuales = delitos_sexuales.filter(['CODIGO DANE','MUNICIPIO','CANTIDAD'], axis = 1)
delitos_sexuales['CODIGO DANE'] = delitos_sexuales['CODIGO DANE']/1000
delitos_sexuales.dropna()
#delitos_sexuales = delitos_sexuales.sort_values(by='MUNICIPIO') ; delitos_sexuales
delitos_sexuales1 = delitos_sexuales.groupby(['CODIGO DANE','MUNICIPIO']).sum()

# %%
extorsion = extorsion.filter(['CODIGO DANE','MUNICIPIO','CANTIDAD'], axis = 1)
extorsion['CODIGO DANE'] = extorsion['CODIGO DANE']/1000
extorsion.dropna()
#extorsion = extorsion.sort_values(by='MUNICIPIO') ; extorsion
extorsion1 = extorsion.groupby(['CODIGO DANE','MUNICIPIO']).sum();

# %%
homicidios = homicidios.filter(['CODIGO DANE','MUNICIPIO','CANTIDAD'], axis = 1)
homicidios['CODIGO DANE'] = homicidios['CODIGO DANE']/1000
homicidios.dropna()
#homicidios = homicidios.sort_values(by='MUNICIPIO') ; homicidios
homicidios1 = homicidios.groupby(['CODIGO DANE','MUNICIPIO']).sum();

# %%
homicidios_en_accidente_de_transito = homicidios_en_accidente_de_transito.filter(['CODIGO DANE','MUNICIPIO','CANTIDAD'], axis = 1)
homicidios_en_accidente_de_transito['CODIGO DANE'] = homicidios_en_accidente_de_transito['CODIGO DANE']/1000
homicidios_en_accidente_de_transito.dropna()
#homicidios_en_accidente_de_transito = homicidios_en_accidente_de_transito.sort_values(by='MUNICIPIO') ; homicidios_en_accidente_de_transito 
homicidios_en_accidente_de_transito1 = homicidios_en_accidente_de_transito.groupby(['CODIGO DANE','MUNICIPIO']).sum()

# %%
hurto_a_comercio = hurto_a_comercio.filter(['CODIGO DANE','MUNICIPIO','CANTIDAD'], axis = 1)
hurto_a_comercio['CODIGO DANE'] = hurto_a_comercio['CODIGO DANE']/1000
hurto_a_comercio.dropna()
#hurto_a_comercio = hurto_a_comercio.sort_values(by='MUNICIPIO') ; hurto_a_comercio
hurto_a_comercio1 = hurto_a_comercio.groupby(['CODIGO DANE','MUNICIPIO']).sum()

# %%
hurto_a_entidades_financieras = hurto_a_entidades_financieras.filter(['CODIGO DANE','MUNICIPIO','CANTIDAD'], axis = 1)
hurto_a_entidades_financieras['CODIGO DANE'] = hurto_a_entidades_financieras['CODIGO DANE']/1000
hurto_a_entidades_financieras.dropna()
#hurto_a_entidades_financieras = hurto_a_entidades_financieras.sort_values(by='MUNICIPIO') ; hurto_a_entidades_financieras
hurto_a_entidades_financieras1 = hurto_a_entidades_financieras.groupby(['CODIGO DANE','MUNICIPIO']).sum();

# %%
hurto_a_personas = hurto_a_personas.filter(['CODIGO DANE','MUNICIPIO','CANTIDAD'], axis = 1)
hurto_a_personas.dropna()
hurto_a_personas['CODIGO DANE'] = hurto_a_personas['CODIGO DANE']/1000
hurto_a_personas.dropna()
#hurto_a_personas = hurto_a_personas.sort_values(by='MUNICIPIO') ; hurto_a_personas
hurto_a_personas1 = hurto_a_personas.groupby(['CODIGO DANE','MUNICIPIO']).sum()

# %%
hurto_a_residencias = hurto_a_residencias.filter(['CODIGO DANE','MUNICIPIO','CANTIDAD'], axis = 1)
hurto_a_residencias['CODIGO DANE'] = hurto_a_residencias['CODIGO DANE']/1000
hurto_a_residencias.dropna()
#hurto_a_residencias = hurto_a_residencias.sort_values(by='MUNICIPIO') ; hurto_a_residencias
hurto_a_residencias1 = hurto_a_residencias.groupby(['CODIGO DANE','MUNICIPIO']).sum();

# %%
hurto_automotores = hurto_automotores.filter(['CODIGO DANE','MUNICIPIO','CANTIDAD'], axis = 1)
hurto_automotores['CODIGO DANE'] = hurto_automotores['CODIGO DANE']/1000
hurto_automotores.dropna()
#hurto_automotores = hurto_automotores.sort_values(by='MUNICIPIO') ; hurto_automotores
hurto_automotores1 = hurto_automotores.groupby(['CODIGO DANE','MUNICIPIO']).sum()

# %%
hurto_motocicletas = hurto_motocicletas.filter(['CODIGO DANE','MUNICIPIO','CANTIDAD'], axis = 1)
hurto_motocicletas['CODIGO DANE'] = hurto_motocicletas['CODIGO DANE']/1000
hurto_motocicletas.dropna()
#hurto_motocicletas = hurto_motocicletas.sort_values(by='MUNICIPIO') ; hurto_motocicletas
hurto_motocicletas1 = hurto_motocicletas.groupby(['CODIGO DANE','MUNICIPIO']).sum()

# %%
lesiones_en_accidente_de_transito = lesiones_en_accidente_de_transito.filter(['CODIGO DANE','MUNICIPIO','CANTIDAD'], axis = 1)
lesiones_en_accidente_de_transito['CODIGO DANE'] = lesiones_en_accidente_de_transito['CODIGO DANE']/1000
lesiones_en_accidente_de_transito.dropna()
#lesiones_en_accidente_de_transito = lesiones_en_accidente_de_transito.sort_values(by='MUNICIPIO') ; lesiones_en_accidente_de_transito
lesiones_en_accidente_de_transito1 = lesiones_en_accidente_de_transito.groupby(['CODIGO DANE','MUNICIPIO']).sum();

# %%
lesiones_personales = lesiones_personales.filter(['CODIGO DANE','MUNICIPIO','CANTIDAD'], axis = 1)
lesiones_personales['CODIGO DANE'] = lesiones_personales['CODIGO DANE']/1000
lesiones_personales.dropna()
#lesiones_personales = lesiones_personales.sort_values(by='MUNICIPIO') ; lesiones_personales
lesiones_personales1 = lesiones_personales.groupby(['CODIGO DANE','MUNICIPIO']).sum();

# %%
pirateria_terrestre = pirateria_terrestre.filter(['CODIGO DANE','MUNICIPIO','CANTIDAD'], axis = 1)
pirateria_terrestre['CODIGO DANE'] = pirateria_terrestre['CODIGO DANE']/1000
pirateria_terrestre.dropna()
#pirateria_terrestre = pirateria_terrestre.sort_values(by='MUNICIPIO') ; pirateria_terrestre
pirateria_terrestre1 = pirateria_terrestre.groupby(['CODIGO DANE','MUNICIPIO']).sum()

# %%
secuestro = secuestro.filter(['CODIGO DANE','MUNICIPIO','CANTIDAD'], axis = 1)
secuestro['CODIGO DANE'] = secuestro['CODIGO DANE']/1000
secuestro.dropna()
#secuestro = secuestro.sort_values(by='MUNICIPIO') ; secuestro
secuestro1 = secuestro.groupby(['CODIGO DANE','MUNICIPIO']).sum();

# %%
terrorismo = terrorismo.filter(['CODIGO DANE','Municipio','CANTIDAD'], axis = 1)
terrorismo['CODIGO DANE'] = terrorismo['CODIGO DANE']/1000
terrorismo.dropna()
#terrorismo = terrorismo.sort_values(by='Municipio') ; terrorismo
terrorismo1 = terrorismo.groupby(['CODIGO DANE','Municipio']).sum();

# %%
violencia_intrafamiliar = violencia_intrafamiliar.filter(['CODIGO DANE','MUNICIPIO','CANTIDAD'], axis = 1)
violencia_intrafamiliar['CODIGO DANE'] = violencia_intrafamiliar['CODIGO DANE']/1000
violencia_intrafamiliar.dropna()
#violencia_intrafamiliar = violencia_intrafamiliar.sort_values(by='MUNICIPIO') ; violencia_intrafamiliar
violencia_intrafamiliar1 = violencia_intrafamiliar.groupby(['CODIGO DANE','MUNICIPIO']).sum();

# %%
Proyeccion_muni = pd.read_excel('/content/Proyeccion por municipio 2019.xlsx'); Proyeccion_muni
Proyeccion_muni.set_index('CODIGO DANE',inplace=True)
Proyeccion_muni
# Out:
#                        MPIO    Total
# CODIGO DANE
# 5001               Medellín  2483545
# 5002              Abejorral    20258
# 5004               Abriaquí     2710
# 5021             Alejandría     4669
# 5030                  Amagá    30777
# ...                     ...      ...
# 97889         Yavaraté (CD)     1067
# 99001        Puerto Carreño    20474
# 99524          La Primavera     9799
# 99624         Santa Rosalía     4130
# 99773              Cumaribo    76196
#
# [1122 rows x 2 columns]

# %%
M = pd.concat([abigeato1,amenazas1,delitos_sexuales1,extorsion1,homicidios1,homicidios_en_accidente_de_transito1,hurto_a_comercio1,hurto_a_entidades_financieras1,hurto_a_personas1,hurto_a_residencias1,hurto_automotores1,hurto_motocicletas1,lesiones_en_accidente_de_transito1,lesiones_personales1,pirateria_terrestre1,secuestro1,terrorismo1,violencia_intrafamiliar1], axis=1)

# %%
M.columns = ['abigeato1','amenazas1','delitos_sexuales1','extorsion1','homicidios1','homicidios_en_accidente_de_transito1','hurto_a_comercio1','hurto_a_entidades_financieras1','hurto_a_personas1','hurto_a_residencias1','hurto_automotores1','hurto_motocicletas1','lesiones_en_accidente_de_transito1','lesiones_personales1','pirateria_terrestre1','secuestro1','terrorismo1','violencia_intrafamiliar1']
M.columns
# Out:
# Index(['abigeato1', 'amenazas1', 'delitos_sexuales1', 'extorsion1',
#        'homicidios1', 'homicidios_en_accidente_de_transito1',
#        'hurto_a_comercio1', 'hurto_a_entidades_financieras1',
#        'hurto_a_personas1', 'hurto_a_residencias1', 'hurto_automotores1',
#        'hurto_motocicletas1', 'lesiones_en_accidente_de_transito1',
#        'lesiones_personales1', 'pirateria_terrestre1', 'secuestro1',
#        'terrorismo1', 'violencia_intrafamiliar1'],
#       dtype='object')

# %%
M = M.rename_axis(['CODIGO DANE','muni']).reset_index()

# %%
#M.drop(['muni'],axis = 1)

# %%
M = M.fillna(0)

# %%
M.set_index('CODIGO DANE',inplace=True)

# %%
S = M.join(Proyeccion_muni, how='outer'); S
# Out:
#                             muni  abigeato1  ...            MPIO      Total
# CODIGO DANE                                  ...
# 0.0                  NO REGISTRA        0.0  ...             NaN        NaN
# 5001.0             MEDELLÍN (CT)        5.0  ...        Medellín  2483545.0
# 5002.0                 ABEJORRAL        1.0  ...       Abejorral    20258.0
# 5004.0                  ABRIAQUÍ        0.0  ...        Abriaquí     2710.0
# 5021.0                ALEJANDRÍA        1.0  ...      Alejandría     4669.0
# ...                          ...        ...  ...             ...        ...
# 97889.0                      NaN        NaN  ...   Yavaraté (CD)     1067.0
# 99001.0      PUERTO CARREÑO (CT)        8.0  ...  Puerto Carreño    20474.0
# 99524.0             LA PRIMAVERA        1.0  ...    La Primavera     9799.0
# 99624.0            SANTA ROSALÍA        0.0  ...   Santa Rosalía     4130.0
# 99773.0                 CUMARIBO        1.0  ...        Cumaribo    76196.0
#
# ...

# %%
s = S[S['muni'].isna()]
s = s.rename_axis('CODIGO DANE').reset_index()
s.isna().sum()
S = S.drop(s['CODIGO DANE'],axis=0);S
S = S.drop([0.0],axis=0)

# %%
S.isna().sum()
# Out:
# muni                                    0
# abigeato1                               0
# amenazas1                               0
# delitos_sexuales1                       0
# extorsion1                              0
# homicidios1                             0
# homicidios_en_accidente_de_transito1    0
# hurto_a_comercio1                       0
# hurto_a_entidades_financieras1          0
# hurto_a_personas1                       0
# hurto_a_residencias1                    0
# hurto_automotores1                      0
# hurto_motocicletas1                     0
# lesiones_en_accidente_de_transito1      0
# lesiones_personales1                    0
# pirateria_terrestre1                    0
# secuestro1                              0
# terrorismo1                             0
# violencia_intrafamiliar1                0
# MPIO                                    0
# Total                                   0
# dtype: int64

# %%
S['abigeato1'] = S['abigeato1']/S['Total']*100000
S['amenazas1'] = S['amenazas1']/S['Total']*100000
S['delitos_sexuales1'] = S['delitos_sexuales1']/S['Total']*100000
S['extorsion1'] = S['extorsion1']/S['Total']*100000
S['homicidios1'] = S['homicidios1']/S['Total']*100000
S['homicidios_en_accidente_de_transito1'] = S['homicidios_en_accidente_de_transito1']/S['Total']*100000
S['hurto_a_comercio1'] = S['hurto_a_comercio1']/S['Total']*100000
S['hurto_a_entidades_financieras1'] = S['hurto_a_entidades_financieras1']/S['Total']*100000
S['hurto_a_personas1'] = S['hurto_a_personas1']/S['Total']*100000
S['hurto_a_residencias1'] = S['hurto_a_residencias1']/S['Total']*100000
S['hurto_motocicletas1'] = S['hurto_motocicletas1']/S['Total']*100000
S['lesiones_en_accidente_de_transito1'] = S['lesiones_en_accidente_de_transito1']/S['Total']*100000
S['lesiones_personales1'] = S['lesiones_personales1']/S['Total']*100000
S['pirateria_terrestre1'] = S['pirateria_terrestre1']/S['Total']*100000
S['secuestro1'] = S['secuestro1']/S['Total']*100000
S['terrorismo1'] = S['terrorismo1']/S['Total']*100000
S['violencia_intrafamiliar1'] = S['violencia_intrafamiliar1']/S['Total']*100000

# %%
S
# Out:
#                             muni  abigeato1  ...            MPIO      Total
# CODIGO DANE                                  ...
# 5001.0             MEDELLÍN (CT)   0.201325  ...        Medellín  2483545.0
# 5002.0                 ABEJORRAL   4.936321  ...       Abejorral    20258.0
# 5004.0                  ABRIAQUÍ   0.000000  ...        Abriaquí     2710.0
# 5021.0                ALEJANDRÍA  21.417862  ...      Alejandría     4669.0
# 5030.0                     AMAGÁ   0.000000  ...           Amagá    30777.0
# ...                          ...        ...  ...             ...        ...
# 97666.0                  TARAIRA   0.000000  ...         Taraira     2318.0
# 99001.0      PUERTO CARREÑO (CT)  39.073947  ...  Puerto Carreño    20474.0
# 99524.0             LA PRIMAVERA  10.205123  ...    La Primavera     9799.0
# 99624.0            SANTA ROSALÍA   0.000000  ...   Santa Rosalía     4130.0
# 99773.0                 CUMARIBO   1.312405  ...        Cumaribo    76196.0
#
# ...

# %% [markdown]
# ### Matriz de inercia

# %%
import seaborn as sns
import plotly.express as px

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
X = S.filter(['abigeato1', 'amenazas1', 'delitos_sexuales1', 'extorsion1',
       'homicidios1', 'homicidios_en_accidente_de_transito1',
       'hurto_a_comercio1', 'hurto_a_entidades_financieras1',
       'hurto_a_personas1', 'hurto_a_residencias1', 'hurto_automotores1',
       'hurto_motocicletas1', 'lesiones_en_accidente_de_transito1',
       'lesiones_personales1', 'pirateria_terrestre1', 'secuestro1',
       'terrorismo1', 'violencia_intrafamiliar1']); X
# Out:
#              abigeato1   amenazas1  ...  terrorismo1  violencia_intrafamiliar1
# CODIGO DANE                         ...
# 5001.0        0.201325   23.997955  ...     0.040265                407.119662
# 5002.0        4.936321    4.936321  ...     0.000000                 78.981143
# 5004.0        0.000000   36.900369  ...     0.000000                  0.000000
# 5021.0       21.417862   42.835725  ...     0.000000                107.089312
# 5030.0        0.000000  100.724567  ...     0.000000                 64.983592
# ...                ...         ...  ...          ...                       ...
# 97666.0       0.000000    0.000000  ...     0.000000                474.547023
# 99001.0      39.073947   97.684869  ...     0.000000                219.790954
# 99524.0      10.205123   51.025615  ...     0.000000                 61.230738
# 99624.0       0.000000    0.000000  ...     0.000000                 48.426150
# ...

# %%
X.corr()
# Out:
#                                       abigeato1  ...  violencia_intrafamiliar1
# abigeato1                              1.000000  ...                  0.083526
# amenazas1                              0.036839  ...                  0.276581
# delitos_sexuales1                      0.107608  ...                  0.354849
# extorsion1                             0.109373  ...                  0.043477
# homicidios1                           -0.095333  ...                 -0.047916
# homicidios_en_accidente_de_transito1   0.217103  ...                  0.117403
# hurto_a_comercio1                      0.146944  ...                  0.377962
# hurto_a_entidades_financieras1         0.017272  ...                  0.001477
# hurto_a_personas1                     -0.013924  ...                  0.425174
# hurto_a_residencias1                   0.261421  ...                  0.351734
# hurto_automotores1                    -0.031755  ...                  0.154105
# ...

# %%
Municipios = S.filter(['muni'])
Indicador_1 = X.index ; Mun = Municipios.to_numpy()
dic_1 = {}
for j in range(X.shape[0]):
  dic_1[Indicador_1[j]] = Mun[j]
X.rename(index = dic_1)
# Out:
#                        abigeato1  ...  violencia_intrafamiliar1
# CODIGO DANE                       ...
# [MEDELLÍN (CT)]         0.201325  ...                407.119662
# [ABEJORRAL]             4.936321  ...                 78.981143
# [ABRIAQUÍ]              0.000000  ...                  0.000000
# [ALEJANDRÍA]           21.417862  ...                107.089312
# [AMAGÁ]                 0.000000  ...                 64.983592
# ...                          ...  ...                       ...
# [TARAIRA]               0.000000  ...                474.547023
# [PUERTO CARREÑO (CT)]  39.073947  ...                219.790954
# [LA PRIMAVERA]         10.205123  ...                 61.230738
# [SANTA ROSALÍA]         0.000000  ...                 48.426150
# [CUMARIBO]              1.312405  ...                  6.562024
#
# [1102 rows x 18 columns]

# %%
X_std = StandardScaler().fit_transform(X); X_std
# Out:
# array([[-0.54842277, -0.79908379,  0.63733602, ..., -0.09533424,
#         -0.11078445,  2.77294959],
#        [-0.37955075, -1.03320424,  0.06528164, ..., -0.15074296,
#         -0.11872556, -0.36810035],
#        [-0.55560297, -0.64061262,  0.85787502, ..., -0.15074296,
#         -0.11872556, -1.12413386],
#        ...,
#        [-0.19164075, -0.46712229, -0.21178839, ..., -0.15074296,
#         -0.11872556, -0.53801308],
#        [-0.55560297, -1.09383356,  2.12905937, ..., -0.15074296,
#         -0.11872556, -0.66058281],
#        [-0.5087965 , -0.85204356, -0.85468485, ..., -0.15074296,
#         -0.11872556, -1.06132   ]])

# %% [markdown]
# #### A mano

# %%
cov = X_std.T.dot(X_std)/X_std.shape[0]

# %%
eigvals, eigvecs = np.linalg.eig(cov)

# %%
varianza_explicada = {i:i/sum(eigvals) for i in (eigvals)} ;varianza_explicada
# Out:
# {0.23092065417994076: 0.012828925232218931,
#  0.3843767733021315: 0.02135426518345175,
#  0.4063148072565807: 0.022573044847587816,
#  0.46523171026827703: 0.02584620612601539,
#  0.5330446531836859: 0.029613591843538106,
#  0.5640174949084906: 0.03133430527269392,
#  0.685489618720067: 0.03808275659555928,
#  0.7148474639587685: 0.03971374799770936,
#  0.7537128698893645: 0.0418729372160758,
#  0.8882919975875191: 0.049349555421528836,
#  0.9540091203263943: 0.053000506684799685,
#  0.9850635053939597: 0.05472575029966443,
#  1.0313078247905052: 0.05729487915502807,
#  1.0681603932995245: 0.05934224407219581,
#  1.2367495549362302: 0.06870830860756834,
#  1.5003531146043256: 0.08335295081135143,
#  1.7867856761753407: 0.09926587089863004,
#  3.8113227672188934: 0.21174015373438296}

# %%
inercia = pd.DataFrame({'eigvals':eigvals,
                       'inercia_acum': np.cumsum(eigvals),
                       'var_expl': varianza_explicada.values(),
                       'v_expl_acum':np.cumsum([i for i in varianza_explicada.values()])})

# %%
inercia.T.round(4)
# Out:
#                   0       1       2       3   ...       14       15       16      17
# eigvals       3.8113  1.7868  1.5004  0.2309  ...   1.0682   1.0313   0.9851   0.954
# inercia_acum  3.8113  5.5981  7.0985  7.3294  ...  15.0296  16.0609  17.0460  18.000
# var_expl      0.2117  0.0993  0.0834  0.0128  ...   0.0593   0.0573   0.0547   0.053
# v_expl_acum   0.2117  0.3110  0.3944  0.4072  ...   0.8350   0.8923   0.9470   1.000
#
# [4 rows x 18 columns]

# %% [markdown]
# ## Con scikit-learn

# %%
pca = PCA()
X_pca = pca.fit_transform(X_std)

# %%
eigvals = pca.explained_variance_ ; eigvals
# Out:
# array([3.81478446, 1.78840855, 1.50171583, 1.23787285, 1.06913057,
#        1.03224453, 0.9859582 , 0.95487561, 0.8890988 , 0.75439744,
#        0.71549674, 0.68611223, 0.56452977, 0.5335288 , 0.46565426,
#        0.40668385, 0.38472589, 0.23113039])

# %%
inercia_acum = eigvals.cumsum(); inercia_acum
# Out:
# array([ 3.81478446,  5.60319301,  7.10490884,  8.3427817 ,  9.41191226,
#        10.44415679, 11.43011499, 12.38499061, 13.27408941, 14.02848685,
#        14.74398358, 15.43009581, 15.99462558, 16.52815438, 16.99380864,
#        17.40049249, 17.78521838, 18.01634877])

# %%
var_expl = pca.explained_variance_ratio_ ; var_expl
# Out:
# array([0.21174015, 0.09926587, 0.08335295, 0.06870831, 0.05934224,
#        0.05729488, 0.05472575, 0.05300051, 0.04934956, 0.04187294,
#        0.03971375, 0.03808276, 0.03133431, 0.02961359, 0.02584621,
#        0.02257304, 0.02135427, 0.01282893])

# %%
v_expl_acum = var_expl.cumsum(); v_expl_acum
# Out:
# array([0.21174015, 0.31100602, 0.39435898, 0.46306728, 0.52240953,
#        0.57970441, 0.63443016, 0.68743066, 0.73678022, 0.77865316,
#        0.8183669 , 0.85644966, 0.88778397, 0.91739756, 0.94324376,
#        0.96581681, 0.98717107, 1.        ])

# %%
inercia_matrix = pd.DataFrame({'eigvals':eigvals,
                               'inercia_acum':inercia_acum,
                               'var_expl': var_expl,
                               'v_expl_acum':v_expl_acum})

# %%
inercia_matrix.T.round(4)
# Out:
#                   0       1       2   ...       15       16       17
# eigvals       3.8148  1.7884  1.5017  ...   0.4067   0.3847   0.2311
# inercia_acum  3.8148  5.6032  7.1049  ...  17.4005  17.7852  18.0163
# var_expl      0.2117  0.0993  0.0834  ...   0.0226   0.0214   0.0128
# v_expl_acum   0.2117  0.3110  0.3944  ...   0.9658   0.9872   1.0000
#
# [4 rows x 18 columns]

# %% [markdown]
# ### Componentes principales
#
# La primera y segunda componete principal explican el $21.17$% y $9.93$% de la varianza total respectivamente, es decir, ambas dimensiones explican el $31.1$% de la varianza total.

# %%
X_pca = pd.DataFrame(X_pca[:,[0,1]], columns = ['PC1', 'PC2']) ; X_pca
# Out:
#            PC1       PC2
# 0     6.434509 -0.788489
# 1    -0.903099 -0.415026
# 2    -1.632611 -0.261982
# 3     1.059333 -0.566186
# 4     0.353516  0.217135
# ...        ...       ...
# 1097  0.153261 -1.714023
# 1098  4.755076  0.800071
# 1099 -1.612057 -0.571049
# 1100 -1.115954 -0.755519
# 1101 -2.820791 -0.681646
#
# [1102 rows x 2 columns]

# %%
Municipios.reset_index(drop=True, inplace=True)
X_pca.reset_index(drop=True,inplace=True)
ACP_mun = pd.concat([X_pca,Municipios], axis=1)

# %%
ACP_mun.columns = ['PC1 (21.174%)','PC2 (9.927%)','Municipio']

# %% [markdown]
# ## Representación grafica

# %% [markdown]
# ### Screen plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
ind = np.arange(1,19) ; ind
(fig, ax) = plt.subplots( figsize = (8,6))
sns.pointplot(x = ind, y = pca.explained_variance_ratio_)
ax.set_title('Screen plot')
ax.set_xticks(ind)
ax.set_xticklabels(ind)
ax.set_xlabel('Numero de componente')
ax.set_ylabel('Varianza Explicada')
plt.show()

# %%
# Componentes.columns = X.columns[[list(range(0,18))]]

# %%
Correlaciones = np.zeros((X_std.shape[1],2))

# %%
for j in range(2):
  for i in range(eigvals.shape[0]):
    Correlaciones[i,j] = eigvecs[i,j] * ( eigvals[j] ** (1/2) )

# %%
Correlaciones = pd.DataFrame(Correlaciones, columns = ['ACP1','ACP2'])

# %%
Correlaciones.index = X.columns

# %%
Correlaciones
# Out:
#                                           ACP1      ACP2
# abigeato1                             0.260204 -0.060595
# amenazas1                             0.349527  0.336603
# delitos_sexuales1                     0.457785  0.004541
# extorsion1                            0.230641  0.453607
# homicidios1                           0.045176  0.731724
# homicidios_en_accidente_de_transito1  0.373956  0.204610
# hurto_a_comercio1                     0.760125 -0.070549
# hurto_a_entidades_financieras1        0.054071  0.081683
# hurto_a_personas1                     0.744483 -0.109964
# hurto_a_residencias1                  0.685082 -0.223825
# hurto_automotores1                    0.239261 -0.064938
# hurto_motocicletas1                   0.445086  0.342359
# lesiones_en_accidente_de_transito1    0.569179 -0.044080
# lesiones_personales1                  0.747934 -0.109235
# pirateria_terrestre1                  0.136930  0.414708
# ...

# %% [markdown]
# En cuanto a la información que proporciona cada componente principal sobre las variables, aquellas con correlaciones de alrededor de 0.6 con almenos una dimesión nos indicara cuales variables contribuyeron a la construccion de cada
# uno de las dimensiones, a continucion se observa que variables estan mejor representadas en cada una de las componentes seleccionadas:
#
# - Primera componente principal: Hurto a comercio, hurto a personas, hurto a residencias, lesiones en accidentes de transito, lesiones personales, violencia intrafamilar.
# - Segunda componente principal: Homicidios, terrorismo.

# %%
Coordenadas = Correlaciones.to_numpy()[[4,6,8,9,12,13,16,17],] ; Coordenadas
# Out:
# array([[ 0.04517625,  0.73172372],
#        [ 0.76012523, -0.07054938],
#        [ 0.74448284, -0.10996357],
#        [ 0.68508161, -0.22382519],
#        [ 0.5691786 , -0.04408014],
#        [ 0.74793373, -0.10923545],
#        [-0.02025296,  0.61101609],
#        [ 0.6766436 , -0.15238774]])

# %%
Names = ['Homicidios', 'Hurto a comercio', 'Hurto a personas', 'Hurto a residencias', 'Lesiones en accidentes de transito', 'Lesiones personales', 'Terrorismo', 'Violencia intrafamiliar']

# %%
(fig, ax) = plt.subplots(figsize=(8,8))
for j in range(0,Coordenadas.shape[0]):
  ax.arrow(0, 0, 
           Coordenadas[j,0], Coordenadas[j,1], 
           head_width = 0.1, head_length = 0.1)

    
an = np.linspace(0, 2 * np.pi,100)
plt.plot(np.cos(an), np.sin(an)) 
plt.axis('equal')
ax.set_title('Representacion grafica')
  
plt.text(Coordenadas[0,0] + 0.1  ,
         Coordenadas[0,1]  ,
         Names[0])

plt.text(Coordenadas[1,0] + 0.12  ,
         Coordenadas[1,1] - 0.02  ,
         Names[1])

plt.text(Coordenadas[2,0] + 0.12  ,
         Coordenadas[2,1] - 0.04  ,
         Names[2])

plt.text(Coordenadas[3,0] + 0.12  ,
         Coordenadas[3,1] - 0.06  ,
         Names[3])

plt.text(Coordenadas[4,0] - 0.12  ,
         Coordenadas[4,1] + 0.05 ,
         Names[4])

plt.text(Coordenadas[5,0] + 0.7  ,
         Coordenadas[5,1] - 0.03 ,
         Names[5])

plt.text(Coordenadas[6,0] + 0.1  ,
         Coordenadas[6,1]  ,
         Names[6])

plt.text(Coordenadas[7,0] + 0.1  ,
         Coordenadas[7,1] - 0.07 ,
         Names[7])
# Out:
# Text(0.7766436030713955, -0.22238773775321272, 'Violencia intrafamiliar')

# %% [markdown]
# En la representación grafica, unicamente se tuvieron en cuenta las variables que estan bien representadas en cada una de las componente principales seleccionadas. En cuanto a las asociaciones tenemos que los delitos por  homicidios y terrorismo presenta una asociación positiva, ademas, estos delitos estan incorrelados con los delitos asociaciados a lesiones en accidentes de transito, hurto a comercio, hurto a personas, violencia intrafamiliar, lesiones personales y hurto a residencias, es decir, existe la ausencia de asociacion por lo menos lineal, por ultimo, los ultimos 6 delitos que se mencionaron cuentan con asociacion positiva.

# %%
import plotly.express as px
fig = px.scatter(ACP_mun, x = 'PC1 (21.174%)', y = 'PC2 (9.927%)', hover_name = 'Municipio')
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d63a85ff-ec3d-4717-99f2-4308c07efe91" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d63a85ff-ec3d-4717-99f2-4308c07efe91")) {
#                     Plotly.newPlot(
#                         'd63a85ff-ec3d-4717-99f2-4308c07efe91',
# ...

# %% [markdown]
# Teniendo en cuenta la representación de las variables en el plano que se observo previamente, el municipio de Fortul tienen los valores mas altos en los delitos asociados a terrorismo y homicidios, por otra parte, Bogotá D.C, Pasto y Cali cuenta con los valores mas altos en los delitos asociaciados a lesiones en accidentes de transito, hurto a comercio, hurto a  personas, lesiones personales, violencia intrafamiliar y hurto a residencias, en contra posición, tenemos que los valores mas pequeños en estos delitos se presentan en los municipios de Hacarí, Cáceres, Providencia, Briceño y Ituango, entre otras cosas, los municipios que se encuentran en el origen son individuos con delitos promedio, como lo son La Gloria, Galan, Urrao, Tello, Chitaraque, entre otros.

# %% [markdown]
# ## Departamento

# %%
abigeato = pd.read_excel('/content/abigeato_2019_3.xlsx')
amenazas = pd.read_excel('/content/amenazas_2019_1.xlsx')
delitos_sexuales = pd.read_excel('/content/delitos_sexuales_2019_0.xlsx')
extorsion = pd.read_excel('/content/extorsion_2019_4.xlsx')
homicidios = pd.read_excel('/content/homicidios_2019_3.xlsx')
homicidios_en_accidente_de_transito = pd.read_excel('/content/homicidios_en_accidente_de_transito_2019.xlsx')
hurto_a_comercio = pd.read_excel('/content/hurto_a_comercio_2019_0.xlsx')
hurto_a_entidades_financieras = pd.read_excel('/content/hurto_a_entidades_financieras_2019_3.xlsx')
hurto_a_personas = pd.read_excel('/content/hurto_a_personas_2019_0.xlsx')
hurto_a_residencias = pd.read_excel('/content/hurto_a_residencias_2019_0.xlsx')
hurto_automotores = pd.read_excel('/content/hurto_automotores_2019_0.xlsx')
hurto_motocicletas = pd.read_excel('/content/hurto_motocicletas_2019_0.xlsx')
lesiones_en_accidente_de_transito = pd.read_excel('/content/lesiones_en_accidente_de_transito_2019_0.xlsx')
lesiones_personales = pd.read_excel('/content/lesiones_personales_2019_0.xlsx')
pirateria_terrestre = pd.read_excel('/content/pirateria_terrestre_2019_3.xlsx')
secuestro = pd.read_excel('/content/secuestro_2019_3.xlsx')
terrorismo = pd.read_excel('/content/terrorismo_2019_2.xlsx')
violencia_intrafamiliar = pd.read_excel('/content/violencia_intrafamiliar_2019_0.xlsx')

# %%
abigeato.columns 
abigeato = pd.read_excel('/content/abigeato_2019_3.xlsx')

# %%
round(abigeato['CODIGO DANE']/1000000)
# Out:
# 0       20.0
# 1       20.0
# 2       20.0
# 3       20.0
# 4       20.0
#         ...
# 3324     8.0
# 3325    19.0
# 3326     NaN
# 3327     NaN
# 3328     NaN
# Name: CODIGO DANE, Length: 3329, dtype: float64

# %%
abigeato = abigeato.filter(['CODIGO DANE','DEPARTAMENTO','CANTIDAD'], axis = 1)
abigeato['CODIGO DANE'] = round(abigeato['CODIGO DANE']//1000000)
abigeato.dropna()
abigeato1 = abigeato.groupby(['CODIGO DANE','DEPARTAMENTO']).sum() ;

# %%
amenazas = amenazas.filter(['CODIGO DANE','DEPARTAMENTO','CANTIDAD'], axis = 1)
amenazas['CODIGO DANE'] = round(amenazas['CODIGO DANE']//1000000)
amenazas.dropna()
amenazas1 = amenazas.groupby(['CODIGO DANE','DEPARTAMENTO']).sum();

# %%
delitos_sexuales = delitos_sexuales.filter(['CODIGO DANE','DEPARTAMENTO','CANTIDAD'], axis = 1)
delitos_sexuales['CODIGO DANE'] = round(delitos_sexuales['CODIGO DANE']//1000000)
delitos_sexuales.dropna()
delitos_sexuales1 = delitos_sexuales.groupby(['CODIGO DANE','DEPARTAMENTO']).sum();

# %%
extorsion = extorsion.filter(['CODIGO DANE','DEPARTAMENTO','CANTIDAD'], axis = 1)
extorsion['CODIGO DANE'] = round(extorsion['CODIGO DANE']//1000000)
extorsion.dropna()
extorsion1 = extorsion.groupby(['CODIGO DANE','DEPARTAMENTO']).sum();

# %%
homicidios = homicidios.filter(['CODIGO DANE','DEPARTAMENTO','CANTIDAD'], axis = 1)
homicidios['CODIGO DANE'] = round(homicidios['CODIGO DANE']//1000000)
homicidios.dropna()
homicidios1 = homicidios.groupby(['CODIGO DANE','DEPARTAMENTO']).sum();

# %%
homicidios_en_accidente_de_transito = homicidios_en_accidente_de_transito.filter(['CODIGO DANE','DEPARTAMENTO','CANTIDAD'], axis = 1)
homicidios_en_accidente_de_transito['CODIGO DANE'] = round(homicidios_en_accidente_de_transito['CODIGO DANE']//1000000)
homicidios_en_accidente_de_transito.dropna()
homicidios_en_accidente_de_transito1 = homicidios_en_accidente_de_transito.groupby(['CODIGO DANE','DEPARTAMENTO']).sum();

# %%
hurto_a_comercio = hurto_a_comercio.filter(['CODIGO DANE','DEPARTAMENTO','CANTIDAD'], axis = 1)
hurto_a_comercio['CODIGO DANE'] = round(hurto_a_comercio['CODIGO DANE']//1000000)
hurto_a_comercio.dropna()
hurto_a_comercio1 = hurto_a_comercio.groupby(['CODIGO DANE','DEPARTAMENTO']).sum();

# %%
hurto_a_entidades_financieras = hurto_a_entidades_financieras.filter(['CODIGO DANE','DEPARTAMENTO','CANTIDAD'], axis = 1)
hurto_a_entidades_financieras['CODIGO DANE'] = round(hurto_a_entidades_financieras['CODIGO DANE']//1000000)
hurto_a_entidades_financieras.dropna()
hurto_a_entidades_financieras1 = hurto_a_entidades_financieras.groupby(['CODIGO DANE','DEPARTAMENTO']).sum();

# %%
hurto_a_personas = hurto_a_personas.filter(['CODIGO DANE','DEPARTAMENTO','CANTIDAD'], axis = 1)
hurto_a_personas.dropna()
hurto_a_personas['CODIGO DANE'] = round(hurto_a_personas['CODIGO DANE']//1000000)
hurto_a_personas1 = hurto_a_personas.groupby(['CODIGO DANE','DEPARTAMENTO']).sum();

# %%
hurto_a_residencias = hurto_a_residencias.filter(['CODIGO DANE','DEPARTAMENTO','CANTIDAD'], axis = 1)
hurto_a_residencias['CODIGO DANE'] = round(hurto_a_residencias['CODIGO DANE']//1000000)
hurto_a_residencias.dropna()
hurto_a_residencias1 = hurto_a_residencias.groupby(['CODIGO DANE','DEPARTAMENTO']).sum();

# %%
hurto_automotores = hurto_automotores.filter(['CODIGO DANE','DEPARTAMENTO','CANTIDAD'], axis = 1)
hurto_automotores['CODIGO DANE'] = round(hurto_automotores['CODIGO DANE']//1000000)
hurto_automotores.dropna()
hurto_automotores1 = hurto_automotores.groupby(['CODIGO DANE','DEPARTAMENTO']).sum();

# %%
hurto_motocicletas = hurto_motocicletas.filter(['CODIGO DANE','DEPARTAMENTO','CANTIDAD'], axis = 1)
hurto_motocicletas['CODIGO DANE'] = round(hurto_motocicletas['CODIGO DANE']//1000000)
hurto_motocicletas.dropna()
hurto_motocicletas1 = hurto_motocicletas.groupby(['CODIGO DANE','DEPARTAMENTO']).sum();

# %%
lesiones_en_accidente_de_transito = lesiones_en_accidente_de_transito.filter(['CODIGO DANE','DEPARTAMENTO','CANTIDAD'], axis = 1)
lesiones_en_accidente_de_transito['CODIGO DANE'] = round(lesiones_en_accidente_de_transito['CODIGO DANE']//1000000)
lesiones_en_accidente_de_transito.dropna()
lesiones_en_accidente_de_transito1 = lesiones_en_accidente_de_transito.groupby(['CODIGO DANE','DEPARTAMENTO']).sum();

# %%
lesiones_personales = lesiones_personales.filter(['CODIGO DANE','DEPARTAMENTO','CANTIDAD'], axis = 1)
lesiones_personales['CODIGO DANE'] = round(lesiones_personales['CODIGO DANE']//1000000)
lesiones_personales.dropna()
lesiones_personales1 = lesiones_personales.groupby(['CODIGO DANE','DEPARTAMENTO']).sum();

# %%
pirateria_terrestre = pirateria_terrestre.filter(['CODIGO DANE','DEPARTAMENTO','CANTIDAD'], axis = 1)
pirateria_terrestre['CODIGO DANE'] = round(pirateria_terrestre['CODIGO DANE']//1000000)
pirateria_terrestre.dropna()
pirateria_terrestre1 = pirateria_terrestre.groupby(['CODIGO DANE','DEPARTAMENTO']).sum();

# %%
secuestro = secuestro.filter(['CODIGO DANE','DEPARTAMENTO','CANTIDAD'], axis = 1)
secuestro['CODIGO DANE'] = round(secuestro['CODIGO DANE']//1000000)
secuestro.dropna()
secuestro1 = secuestro.groupby(['CODIGO DANE','DEPARTAMENTO']).sum();

# %%
terrorismo = terrorismo.filter(['CODIGO DANE','Departamento','CANTIDAD'], axis = 1)
terrorismo['CODIGO DANE'] = round(terrorismo['CODIGO DANE']//1000000)
terrorismo.dropna()
terrorismo1 = terrorismo.groupby(['CODIGO DANE','Departamento']).sum();

# %%
violencia_intrafamiliar = violencia_intrafamiliar.filter(['CODIGO DANE','DEPARTAMENTO','CANTIDAD'], axis = 1)
violencia_intrafamiliar['CODIGO DANE'] = round(violencia_intrafamiliar['CODIGO DANE']//1000000)
violencia_intrafamiliar.dropna()
violencia_intrafamiliar1 = violencia_intrafamiliar.groupby(['CODIGO DANE','DEPARTAMENTO']).sum();

# %%
Proyeccion_muni.columns
# Out:
# Index(['MPIO', 'Total'], dtype='object')

# %%
Proyeccion_dep = pd.read_excel('/content/Proyeccion por departamento.xlsx'); Proyeccion_dep
Proyeccion_dep.set_index('DP',inplace=True)
Proyeccion_dep
# Out:
#                          DPNOM    Total
# DP
# 5                    Antioquia  6550206
# 8                    Atlántico  2638151
# 11                Bogotá, D.C.  7592871
# 13                     Bolívar  2130512
# 15                      Boyacá  1230910
# 17                      Caldas  1008344
# 18                     Caquetá   406142
# 19                       Cauca  1478407
# 20                       Cesar  1252398
# 23                     Córdoba  1808439
# 25                Cundinamarca  3085522
# 27                       Chocó   539933
# 41                       Huila  1111844
# 44                  La Guajira   927506
# 47                   Magdalena  1388832
# 50                        Meta  1052125
# 52                      Nariño  1628981
# 54          Norte de Santander  1565362
# 63                     Quindio   547855
# 66                   Risaralda   952511
# 68                   Santander  2237587
# 70                       Sucre   928984
# ...

# %%
D = pd.concat([abigeato1,amenazas1,delitos_sexuales1,extorsion1,homicidios1,homicidios_en_accidente_de_transito1,hurto_a_comercio1,hurto_a_entidades_financieras1,hurto_a_personas1,hurto_a_residencias1,hurto_automotores1,hurto_motocicletas1,lesiones_en_accidente_de_transito1,lesiones_personales1,pirateria_terrestre1,secuestro1,terrorismo1,violencia_intrafamiliar1], axis=1)

# %%
D.columns = ['abigeato1','amenazas1','delitos_sexuales1','extorsion1','homicidios1','homicidios_en_accidente_de_transito1','hurto_a_comercio1','hurto_a_entidades_financieras1','hurto_a_personas1','hurto_a_residencias1','hurto_automotores1','hurto_motocicletas1','lesiones_en_accidente_de_transito1','lesiones_personales1','pirateria_terrestre1','secuestro1','terrorismo1','violencia_intrafamiliar1']
D.columns
# Out:
# Index(['abigeato1', 'amenazas1', 'delitos_sexuales1', 'extorsion1',
#        'homicidios1', 'homicidios_en_accidente_de_transito1',
#        'hurto_a_comercio1', 'hurto_a_entidades_financieras1',
#        'hurto_a_personas1', 'hurto_a_residencias1', 'hurto_automotores1',
#        'hurto_motocicletas1', 'lesiones_en_accidente_de_transito1',
#        'lesiones_personales1', 'pirateria_terrestre1', 'secuestro1',
#        'terrorismo1', 'violencia_intrafamiliar1'],
#       dtype='object')

# %%
D = D.rename_axis(['DP','Departamento']).reset_index()

# %%
D.set_index('DP',inplace=True)

# %%
D.loc[52.0,'hurto_a_personas1'] = 5854.0
D = D.drop([0.0],axis=0);

# %%
BD = D.join(Proyeccion_dep, how='outer');
# Out:
#             Departamento  abigeato1  ...                       DPNOM    Total
# DP                                   ...
# 5.0            ANTIOQUIA      178.0  ...                   Antioquia  6550206
# 8.0            ATLÁNTICO       73.0  ...                   Atlántico  2638151
# 11.0        CUNDINAMARCA       15.0  ...                Bogotá, D.C.  7592871
# 13.0             BOLÍVAR      239.0  ...                     Bolívar  2130512
# 15.0              BOYACÁ      129.0  ...                      Boyacá  1230910
# 17.0              CALDAS       30.0  ...                      Caldas  1008344
# 18.0             CAQUETÁ       20.0  ...                     Caquetá   406142
# 19.0               CAUCA       91.0  ...                       Cauca  1478407
# 20.0               CESAR      282.0  ...                       Cesar  1252398
# 23.0             CÓRDOBA      142.0  ...                     Córdoba  1808439
# ...

# %%
BD = BD.fillna(0);

# %%
BD.isna().sum()
# Out:
# Departamento                            0
# abigeato1                               0
# amenazas1                               0
# delitos_sexuales1                       0
# extorsion1                              0
# homicidios1                             0
# homicidios_en_accidente_de_transito1    0
# hurto_a_comercio1                       0
# hurto_a_entidades_financieras1          0
# hurto_a_personas1                       0
# hurto_a_residencias1                    0
# hurto_automotores1                      0
# hurto_motocicletas1                     0
# lesiones_en_accidente_de_transito1      0
# lesiones_personales1                    0
# pirateria_terrestre1                    0
# secuestro1                              0
# terrorismo1                             0
# violencia_intrafamiliar1                0
# DPNOM                                   0
# Total                                   0
# dtype: int64

# %%
BD['abigeato1'] = BD['abigeato1']/BD['Total']*100000
BD['amenazas1'] = BD['amenazas1']/BD['Total']*100000
BD['delitos_sexuales1'] = BD['delitos_sexuales1']/BD['Total']*100000
BD['extorsion1'] = BD['extorsion1']/BD['Total']*100000
BD['homicidios1'] = BD['homicidios1']/BD['Total']*100000
BD['homicidios_en_accidente_de_transito1'] = BD['homicidios_en_accidente_de_transito1']/BD['Total']*100000
BD['hurto_a_comercio1'] = BD['hurto_a_comercio1']/BD['Total']*100000
BD['hurto_a_entidades_financieras1'] = BD['hurto_a_entidades_financieras1']/BD['Total']*100000
BD['hurto_a_personas1'] = BD['hurto_a_personas1']/BD['Total']*100000
BD['hurto_a_residencias1'] = BD['hurto_a_residencias1']/BD['Total']*100000
BD['hurto_motocicletas1'] = BD['hurto_motocicletas1']/BD['Total']*100000
BD['lesiones_en_accidente_de_transito1'] = BD['lesiones_en_accidente_de_transito1']/BD['Total']*100000
BD['lesiones_personales1'] = BD['lesiones_personales1']/BD['Total']*100000
BD['pirateria_terrestre1'] = BD['pirateria_terrestre1']/BD['Total']*100000
BD['secuestro1'] = BD['secuestro1']/BD['Total']*100000 
BD['terrorismo1'] = BD['terrorismo1']/BD['Total']*100000
BD['violencia_intrafamiliar1'] = BD['violencia_intrafamiliar1']/BD['Total']*100000

# %%
BD
# Out:
#             Departamento  abigeato1  ...                       DPNOM    Total
# DP                                   ...
# 5.0            ANTIOQUIA   2.717472  ...                   Antioquia  6550206
# 8.0            ATLÁNTICO   2.767090  ...                   Atlántico  2638151
# 11.0        CUNDINAMARCA   0.197554  ...                Bogotá, D.C.  7592871
# 13.0             BOLÍVAR  11.217961  ...                     Bolívar  2130512
# 15.0              BOYACÁ  10.480051  ...                      Boyacá  1230910
# 17.0              CALDAS   2.975175  ...                      Caldas  1008344
# 18.0             CAQUETÁ   4.924386  ...                     Caquetá   406142
# 19.0               CAUCA   6.155274  ...                       Cauca  1478407
# 20.0               CESAR  22.516804  ...                       Cesar  1252398
# 23.0             CÓRDOBA   7.852076  ...                     Córdoba  1808439
# ...

# %% [markdown]
# ### Matriz inercia

# %%
X2 = BD.filter(['abigeato1', 'amenazas1', 'delitos_sexuales1', 'extorsion1',
       'homicidios1', 'homicidios_en_accidente_de_transito1',
       'hurto_a_comercio1', 'hurto_a_entidades_financieras1',
       'hurto_a_personas1', 'hurto_a_residencias1', 'hurto_automotores1',
       'hurto_motocicletas1', 'lesiones_en_accidente_de_transito1',
       'lesiones_personales1', 'pirateria_terrestre1', 'secuestro1',
       'terrorismo1', 'violencia_intrafamiliar1']); X2
# Out:
#       abigeato1   amenazas1  ...  terrorismo1  violencia_intrafamiliar1
# DP                           ...
# 5.0    2.717472   31.632593  ...     1.083935                257.854486
# 8.0    2.767090   67.774741  ...     0.000000                119.818767
# 11.0   0.197554   85.791001  ...     0.013170                476.512771
# 13.0  11.217961   87.068273  ...     0.000000                159.492178
# 15.0  10.480051  128.441559  ...     0.081241                296.609825
# 17.0   2.975175   61.883643  ...     0.000000                138.841506
# 18.0   4.924386  151.178652  ...     0.492439                123.602090
# 19.0   6.155274  161.322288  ...     0.676404                209.279312
# 20.0  22.516804  132.066643  ...     0.000000                101.245770
# 23.0   7.852076  132.102880  ...     0.000000                113.191543
# 25.0  13.806416   57.105410  ...     0.032409                236.070266
# 27.0   0.740833   98.715952  ...     0.370416                 47.042874
# ...

# %%
Departamentos = BD.filter(['Departamento']) ; Departamentos
Indicador_2 = X2.index ; Dep = Departamentos.to_numpy() ; Indicador_2
dic_2 = {}
for j in range(X2.shape[0]):
  dic_2[Indicador_2[j]] = Dep[j]
dic_2
X2.rename(index = dic_2)
# Out:
#                       abigeato1  ...  violencia_intrafamiliar1
# DP                               ...
# [ANTIOQUIA]            2.717472  ...                257.854486
# [ATLÁNTICO]            2.767090  ...                119.818767
# [CUNDINAMARCA]         0.197554  ...                476.512771
# [BOLÍVAR]             11.217961  ...                159.492178
# [BOYACÁ]              10.480051  ...                296.609825
# [CALDAS]               2.975175  ...                138.841506
# [CAQUETÁ]              4.924386  ...                123.602090
# [CAUCA]                6.155274  ...                209.279312
# [CESAR]               22.516804  ...                101.245770
# [CÓRDOBA]              7.852076  ...                113.191543
# [CUNDINAMARCA]        13.806416  ...                236.070266
# [CHOCÓ]                0.740833  ...                 47.042874
# [HUILA]                9.353830  ...                210.731002
# ...

# %% [markdown]
# #### A mano

# %%
X2_std = StandardScaler().fit_transform(X2);

# %%
cov = X2_std.T.dot(X2_std)/X2_std.shape[0]

# %%
eigvals, eigvecs = np.linalg.eig(cov)

# %%
varianza_explicada = {i:i/sum(eigvals) for i in (eigvals)} ;varianza_explicada
# Out:
# {0.011679380173852833: 0.0006488544541029345,
#  0.033611601934713166: 0.001867311218595174,
#  0.045766452473039704: 0.0025425806929466476,
#  0.05783874142515462: 0.003213263412508587,
#  0.07690188415106501: 0.004272326897281385,
#  0.12047451407723009: 0.00669302855984611,
#  0.1456903332333841: 0.008093907401854663,
#  0.24161728768977042: 0.013423182649431677,
#  0.2994325199130633: 0.016635139995170165,
#  0.3772142016046535: 0.020956344533591843,
#  0.5614970178381219: 0.031194278768784518,
#  0.8354319841794473: 0.04641288800996925,
#  1.4146534674731848: 0.07859185930406574,
#  1.6111411249050538: 0.0895078402725029,
#  1.7869166761879898: 0.09927314867711044,
#  2.1189417867621723: 0.1177189881534539,
#  3.6893043988865077: 0.20496135549369468,
#  4.571886627091614: 0.25399370150508943}

# %%
inercia = pd.DataFrame({'eigvals':eigvals,
                       'inercia_acum': np.cumsum(eigvals),
                       'var_expl': varianza_explicada.values(),
                       'v_expl_acum':np.cumsum([i for i in varianza_explicada.values()])})

# %%
inercia.T.round(4)
# Out:
#                   0       1        2   ...       15       16       17
# eigvals       4.5719  3.6893   2.1189  ...   0.0336   0.0458   0.0578
# inercia_acum  4.5719  8.2612  10.3801  ...  17.8964  17.9422  18.0000
# var_expl      0.2540  0.2050   0.1177  ...   0.0019   0.0025   0.0032
# v_expl_acum   0.2540  0.4590   0.5767  ...   0.9942   0.9968   1.0000
#
# [4 rows x 18 columns]

# %% [markdown]
# #### Con scikit-learn

# %%
pca2 = PCA()
X_pca2 = pca.fit_transform(X2_std)

# %%
eigvals = pca.explained_variance_ ; eigvals
# Out:
# array([4.71475808, 3.80459516, 2.18515872, 1.84275782, 1.66148929,
#        1.45886139, 0.86153923, 0.5790438 , 0.38900215, 0.30878979,
#        0.24916783, 0.15024316, 0.12423934, 0.07930507, 0.0596462 ,
#        0.04719665, 0.03466196, 0.01204436])

# %%
inercia_acum = eigvals.cumsum(); inercia_acum
# Out:
# array([ 4.71475808,  8.51935325, 10.70451196, 12.54726979, 14.20875907,
#        15.66762046, 16.52915969, 17.10820349, 17.49720564, 17.80599542,
#        18.05516325, 18.20540641, 18.32964575, 18.40895082, 18.46859702,
#        18.51579367, 18.55045564, 18.5625    ])

# %%
var_expl = pca.explained_variance_ratio_ ; var_expl
# Out:
# array([0.2539937 , 0.20496136, 0.11771899, 0.09927315, 0.08950784,
#        0.07859186, 0.04641289, 0.03119428, 0.02095634, 0.01663514,
#        0.01342318, 0.00809391, 0.00669303, 0.00427233, 0.00321326,
#        0.00254258, 0.00186731, 0.00064885])

# %%
v_expl_acum = var_expl.cumsum(); v_expl_acum
# Out:
# array([0.2539937 , 0.45895506, 0.57667405, 0.67594719, 0.76545503,
#        0.84404689, 0.89045978, 0.92165406, 0.9426104 , 0.95924554,
#        0.97266873, 0.98076263, 0.98745566, 0.99172799, 0.99494125,
#        0.99748383, 0.99935115, 1.        ])

# %%
inercia_matrix = pd.DataFrame({'eigvals':eigvals, 
                               'inercia_acum':inercia_acum, 
                               'var_expl': var_expl, 
                                'v_expl_acum':v_expl_acum})

# %%
inercia_matrix.T.round(4)
# Out:
#                   0       1        2   ...       15       16       17
# eigvals       4.7148  3.8046   2.1852  ...   0.0472   0.0347   0.0120
# inercia_acum  4.7148  8.5194  10.7045  ...  18.5158  18.5505  18.5625
# var_expl      0.2540  0.2050   0.1177  ...   0.0025   0.0019   0.0006
# v_expl_acum   0.2540  0.4590   0.5767  ...   0.9975   0.9994   1.0000
#
# [4 rows x 18 columns]

# %% [markdown]
# ### Componentes principales
#
# La primera y segunda componete principal explican el $25.4$% y $20.5$% de la varianza total respectivamente, es decir, ambas dimensiones explican el $45.9$% de la varianza total.

# %%
X_pca2 = pd.DataFrame(X_pca2[:,[0,1]], columns = ['PC1', 'PC2']) ; X_pca2
# Out:
#          PC1       PC2
# 0   1.221894 -0.120718
# 1  -0.537635 -1.332035
# 2   6.050894 -2.514704
# 3  -0.977691 -1.090375
# 4   0.281623 -1.321008
# 5  -1.097660 -1.706400
# 6  -0.878663  1.495980
# 7   0.031568  2.798730
# 8  -1.146443  0.089693
# 9  -2.264477 -0.442657
# 10  0.950925 -1.409103
# 11 -2.706720  0.517580
# 12  0.509662  0.029336
# 13 -2.120228  0.012411
# 14 -1.322629 -0.615640
# 15  1.854199  1.304135
# 16 -0.954098  0.134966
# 17 -1.011574  0.785513
# 18  1.146183 -0.528007
# 19  0.855944 -1.150117
# 20  0.893117 -1.193547
# 21 -1.163931 -0.977068
# 22  1.874666  0.044754
# 23  2.162210  1.204207
# 24 -1.221582  8.195988
# 25  1.121720  0.440030
# 26 -2.193799  1.078646
# 27  6.937560  2.304992
# 28  0.339664 -1.875736
# 29 -0.682879 -1.597285
# 30 -1.080184  0.948232
# 31 -1.655220 -2.015590
# 32 -3.216416 -1.495203

# %%
X_pca2.reset_index(drop=True, inplace=True)
Departamentos.reset_index(drop=True, inplace=True)
ACP_dep = pd.concat([X_pca2, Departamentos], axis=1)

# %%
ACP_dep.columns = ['PC1 (25.4%)','PC2 (20.5%)','Departamento']

# %% [markdown]
# ### Representación grafica

# %% [markdown]
# #### Screen plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
ind = np.arange(1,19) ; ind
(fig, ax) = plt.subplots( figsize = (8,6))
sns.pointplot(x = ind, y = var_expl)
ax.set_title('Screen plot')
ax.set_xticks(ind)
ax.set_xticklabels(ind)
ax.set_xlabel('Numero de componente')
ax.set_ylabel('Varianza Explicada')
plt.show()

# %%
Correlaciones = np.zeros((X_std.shape[1],2)) 
for j in range(2):
  for i in range(eigvals.shape[0]):
    Correlaciones[i,j] = eigvecs[i,j] * ( eigvals[j] ** (1/2) )
Correlaciones = pd.DataFrame(Correlaciones, columns = ['ACP1','ACP2'])
Correlaciones.index = X.columns

# %%
Correlaciones
# Out:
#                                           ACP1      ACP2
# abigeato1                            -0.027700  0.134836
# amenazas1                            -0.033120  0.504565
# delitos_sexuales1                     0.295586  0.072231
# extorsion1                           -0.097065  0.775996
# homicidios1                          -0.004671  0.803488
# homicidios_en_accidente_de_transito1  0.547586  0.582056
# hurto_a_comercio1                     0.890189 -0.139641
# hurto_a_entidades_financieras1        0.629408  0.055745
# hurto_a_personas1                     0.808812 -0.174016
# hurto_a_residencias1                  0.720484  0.031934
# hurto_automotores1                    0.536432 -0.127026
# hurto_motocicletas1                   0.182169  0.587554
# lesiones_en_accidente_de_transito1    0.491992  0.090061
# lesiones_personales1                  0.837084  0.028646
# pirateria_terrestre1                 -0.089630  0.762249
# ...

# %% [markdown]
# En cuanto a la información que proporciona cada componente principal sobre las variables, aquellas con correlaciones de alrededor de 0.8 con almenos una dimesión nos indicara cuales variables contribuyeron a la construccion de cada
# uno de las dimensiones, a continucion se observa que variables estan mejor representadas en cada una de las componentes seleccionadas:
#
# - Primera componente principal: Hurto a comercio, Hurto a personas, lesiones personales, violencia intrafamiliar.
# - Segunda componente principal: Extorcion, Homicidios, pirateria, terrorismo.

# %%
Coordenadas = Correlaciones.to_numpy()[[3,4,6,8,13,14,16,17],]

# %%
Coordenadas
# Out:
# array([[-0.09706549,  0.7759958 ],
#        [-0.00467132,  0.8034876 ],
#        [ 0.89018863, -0.13964081],
#        [ 0.80881184, -0.17401566],
#        [ 0.83708366,  0.02864648],
#        [-0.0896295 ,  0.76224939],
#        [-0.09934077,  0.78639368],
#        [ 0.78625222, -0.15356362]])

# %%
Names = ['Extorcion', 'Homicidios', 'Hurto a comercio', 'Hurto a personas','Lesiones personales', 'Pirateria terrestre', 'Terrorismo', 'Violencia intrafamiliar']

# %%
(fig, ax) = plt.subplots(figsize=(8,8))
for j in range(0,Coordenadas.shape[0]):
  ax.arrow(0, 0, 
           Coordenadas[j,0], Coordenadas[j,1], 
           head_width = 0.1, head_length = 0.1)
    
an = np.linspace(0, 2 * np.pi,100)
plt.plot(np.cos(an), np.sin(an)) 
plt.axis('equal')
ax.set_title('Representacion grafica')

plt.text(Coordenadas[0,0] + 0.15  ,
         Coordenadas[0,1] + 0.05  ,
         Names[0])

plt.text(Coordenadas[1,0] + 0.4 ,
         Coordenadas[1,1] + 0.02,
         Names[1])

plt.text(Coordenadas[2,0] + 0.1 ,
         Coordenadas[2,1] + 0,
         Names[2])

plt.text(Coordenadas[3,0] + 0.2 ,
         Coordenadas[3,1] - 0.02,
         Names[3])

plt.text(Coordenadas[4,0] + 0.1 ,
         Coordenadas[4,1] + 0,
         Names[4])

plt.text(Coordenadas[5,0] - 0.5 ,
         Coordenadas[5,1] + 0,
         Names[5])

plt.text(Coordenadas[6,0] - 0.3 ,
         Coordenadas[6,1] + 0.06,
         Names[6])

plt.text(Coordenadas[7,0] + 0 ,
         Coordenadas[7,1] - 0.1,
         Names[7])
# Out:
# Text(0.7862522235943961, -0.25356362176044855, 'Violencia intrafamiliar')

# %% [markdown]
# En la representación grafica, unicamente se tuvieron en cuenta las variables que estan bien representadas en cada una de las componente principales seleccionadas. En cuanto a las asociaciones tenemos que los delitos por pirateria terrestre, terrorismo, extorcion y homicidios presentan una asociación positiva, ademas, estos delitos estan incorrelados con los delitos asociaciados a lesiones personales, hurto a comercio, hurto a personas y vilencia intrafamiliar, es decir, existe la ausencia de asociación por lo menos lineal, por ultimo, los ultimos 4 delitos que se mencionaron cuentan con una asoaciación positiva.

# %%
import plotly.express as px
fig = px.scatter(ACP_dep, x = 'PC1 (25.4%)', y = 'PC2 (20.5%)', hover_name = 'Departamento')
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="098ce6f5-5d9d-4a2e-94ce-9f4845f5d64b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("098ce6f5-5d9d-4a2e-94ce-9f4845f5d64b")) {
#                     Plotly.newPlot(
#                         '098ce6f5-5d9d-4a2e-94ce-9f4845f5d64b',
# ...

# %% [markdown]
# Teniendo en cuenta la representación de las variables en el plano que se observo previamente, el departamento de Arauca tiene los valores mas altos en los delitos asociados a terrorismo, pirateria terrestre, extorcion y homicidios, en contra posición los valores mas pequños en estos delitos se presentan en los departamentos de Cundinamarca y Amazonas, por otro parte, San Andrés y Valle tienen los valores mas grandes en delitos asociados a lesiones personales mientras que Vichada y Vaupés tienen los valores mas pequeños en cuanto a estos delitos, ademas, los departamentos de Cundinamarca, Santander y Risaralda, tienen los valores mas altos en los crimenes de lesiones personales, hurto a personas y a comercio, por ultimo, los departamentos de Huila, Nariño y Atlantico son individuos con delitos promedio.
